# %%
# !pip install pyspark py4j
# Out:
# Collecting pyspark
#   Downloading pyspark-3.5.1.tar.gz (317.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.0/317.0 MB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: py4j in /usr/local/lib/python3.10/dist-packages (0.10.9.7)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.5.1-py2.py3-none-any.whl size=317488491 sha256=d1393c6af37bc524723cee6423bbdccd4cfd279b2290ebafde685194866aafd1
#   Stored in directory: /root/.cache/pip/wheels/80/1d/60/2c256ed38dddce2fdd93be545214a63e02fbd8d74fb0b7f3a6
# Successfully built pyspark
# Installing collected packages: pyspark
# Successfully installed pyspark-3.5.1

# %% [markdown]
# ![9 different shoes](https://image-cdn.hypb.st/https%3A%2F%2Fhypebeast.com%2Fwp-content%2Fblogs.dir%2F6%2Ffiles%2F2019%2F07%2Fsneaker-birthstones-nike-adidas-gucci-balenciaga-01-1.jpg?cbr=1&q=90)

# %% [markdown]
# # **Data Manipulation of Shoe Prices**
#
# This project is divided into two parts: **Data Manipulation using Resilient Distributed Datasets (RDD)** and **Data  Manipulation using DataFrame.**
#
# By the end of this project, I aim to answer the following questions by running SQL query:
# 1. What is the average price of different types of shoes?
# 2. What is the most expensive model per type of shoe?
# 3. How does the shoe material affect the price?

# %% [markdown]
# ### **Part 1: Data Manipulation using an RDD**

# %%
from pyspark.sql import SparkSession

# Create a SparkSession
spark = SparkSession.builder \
    .appName("ShoePricesApp") \
    .getOrCreate()

data_rdd = spark.sparkContext.textFile('shoe-prices.csv')
print(f'The number of rows in the RDD is: {data_rdd.count()}')
# Out:
# The number of rows in the RDD is: 1007

# %%
print('These are the first 20 rows of the dataset:')
data_rdd.take(20)
# Out:
# These are the first 20 rows of the dataset:
# ['Brand,Model,Type,Gender,Size,Color,Material,Price (USD)',
#  'Nike,Air Jordan 1,Basketball,Men,US 10,Red/Black,Leather,$170.00 ',
#  'Adidas,Ultra Boost 21,Running,Men,US 9.5,Black,Primeknit,$180.00 ',
#  'Reebok,Classic Leather,Casual,Men,US 11,White,Leather,$75.00 ',
#  'Converse,Chuck Taylor,Casual,Women,US 8,Navy,Canvas,$55.00 ',
#  'Puma,Future Rider,Lifestyle,Women,US 7.5,Pink,Mesh,$80.00 ',
#  'Vans,Old Skool,Skate,Men,US 8.5,Black/White,Suede/Canvas,$65.00 ',
#  'New Balance,990v5,Running,Women,US 6.5,Grey,Suede/Mesh,$175.00 ',
#  'Asics,Gel-Kayano 28,Running,Men,US 10.5,Blue,Mesh,$160.00 ',
#  'Fila,Disruptor II,Fashion,Women,US 9,White,Leather/Synthetic,$65.00 ',
#  'Skechers,Go Run Razor 3,Running,Men,US 9,Black,Mesh,$110.00 ',
#  'Nike,Air Max 270,Running,Women,US 7,Pink,Mesh,$150.00 ',
#  'Adidas,Stan Smith,Casual,Men,US 9,White/Green,Leather,$80.00 ',
#  'Reebok,Club C 85,Casual,Women,US 8.5,Pink,Leather,$70.00 ',
#  'Converse,One Star,Skate,Men,US 10,Black,Suede,$75.00 ',
#  'Puma,RS-Fast,Lifestyle,Men,US 9.5,Yellow,Leather/Synthetic,$110.00 ',
#  'Vans,Authentic,Skate,Women,US 6,White,Canvas,$50.00 ',
#  'New Balance,Fresh Foam 1080v11,Running,Men,US 11.5,Blue,Mesh,$150.00 ',
#  'Asics,Gel-Nimbus 23,Running,Women,US 8,Purple,Mesh,$150.00 ',
#  'Fila,Ray Tracer,Fashion,Men,US 10,Black,Synthetic,$70.00 ']

# %%
# Function to parse the CSV data
def parse_csv(row):
    return row.split(',')

# Parse the data
parsed_data_rdd = data_rdd.map(parse_csv)

# Filter out the header row
header = parsed_data_rdd.first()
data_no_header_rdd = parsed_data_rdd.filter(lambda row: row != header)
print('Without the header, this is now the first row:')
data_no_header_rdd.first()
# Out:
# Without the header, this is now the first row:
# ['Nike',
#  'Air Jordan 1',
#  'Basketball',
#  'Men',
#  'US 10',
#  'Red/Black',
#  'Leather',
#  '$170.00 ']

# %%
# Function to clean each row
def clean_row(row):
    row[4] = row[4].replace("US ", "") # Remove "US" from the Size column
    row[7] = row[7].replace("$", "").strip() # Remove "$" and any whitespace from the Price column
    return row

# Apply the clean_row function to each row
cleaned_data_rdd = data_no_header_rdd.map(clean_row)

# Show the first few rows of the cleaned data
cleaned_data_rdd.take(3)
# Out:
# [['Nike',
#   'Air Jordan 1',
#   'Basketball',
#   'Men',
#   '10',
#   'Red/Black',
#   'Leather',
#   '170.00'],
#  ['Adidas',
#   'Ultra Boost 21',
#   'Running',
#   'Men',
#   '9.5',
#   'Black',
#   'Primeknit',
#   '180.00'],
#  ['Reebok',
#   'Classic Leather',
#   'Casual',
#   'Men',
#   '11',
#   'White',
#   'Leather',
#   '75.00']]

# %%
# Group by Brand
def to_key_value(row):
    return (row[0], row)  # Use the brand as the key

brand_rdd = cleaned_data_rdd.map(to_key_value)

# Sort brands alphabetically before grouping (optional)
sorted_brand_rdd = brand_rdd.sortByKey()

# Group by the sorted brands
grouped_by_brand_rdd = sorted_brand_rdd.groupByKey()

# Show the grouped data for a few brands
for brand, rows in grouped_by_brand_rdd.collect():
    print(f"Brand: {brand}")
    for row in rows:
        print(row)
    print()
# Out:
# Brand: Adidas
# ['Adidas', 'Ultra Boost 21', 'Running', 'Men', '9.5', 'Black', 'Primeknit', '180.00']
# ['Adidas', 'Stan Smith', 'Casual', 'Men', '9', 'White/Green', 'Leather', '80.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Black/Pink', 'Primeknit', '140.00']
# ['Adidas', 'Adizero Adios 5', 'Running', 'Women', '7.5', 'Blue', 'Mesh', '170.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '9', 'Black', 'Knit', '140.00']
# ['Adidas', 'Adilette Cloudfoam', 'Slides', 'Women', '6', 'Black', 'Synthetic', '35.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Men', '10', 'Black', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Men', '8.5', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'Harden Stepback', 'Basketball', 'Men', '12', 'Grey', 'Synthetic', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '8.5', 'Black/White', 'Leather', '80.00']
# ['Adidas', 'Ultraboost 5.0 DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '8', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'Black/White', 'Leather', '85.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Men', '11.5', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost 6.0', 'Running', 'Women', '7.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost 4.0', 'Running', 'Women', '7', 'Blue', 'Primeknit', '180.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Men', '9', 'Black/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Adilette Comfort', 'Slides', 'Women', '6', 'Black', 'Synthetic', '35.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Men', '9', 'Zebra', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Women', '8.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Pink', 'Knit', '140.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '9.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Black/Pink', 'Knit', '140.00']
# ['Adidas', 'Adizero Boston 9', 'Running', 'Women', '6.5', 'Black', 'Mesh', '120.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '8.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1 V2', 'Casual', 'Women', '6.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Ultraboost 5.0 DNA', 'Running', 'Men', '9', 'White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '6', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Black/Pink', 'Primeknit', '130.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Women', '6.5', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'ZX 2K Boost', 'Casual', 'Women', '7.5', 'White/Pink', 'Mesh/Synthetic', '150.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cream White', 'Primeknit/Synthetic', '220.00']
# ['Adidas', 'NMD_R1', 'Fashion', 'Women', '7', 'Grey', 'Knit/Synthetic', '140.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '7', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Ultraboost 20', 'Running', 'Men', '9.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Grey', 'Primeknit', '130.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '10', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '6.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Women', '6.5', 'Cloud White', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8.5', 'Black/Pink', 'Knit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'White/Black', 'Primeknit', '140.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '7.5', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Harden Vol. 5', 'Basketball', 'Women', '8.5', 'Grey', 'Textile', '130.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Adilette Shower', 'Slides', 'Women', '6', 'Pink', 'Synthetic', '25.00']
# ['Adidas', 'Yeezy Boost 350', 'Fashion', 'Women', '8', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Ultraboost 6.0', 'Running', 'Women', '7', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8.5', 'Grey/Pink', 'Primeknit', '140.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '11', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '11', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black/Grey', 'Primeknit', '130.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '9', 'Natural', 'Primeknit', '220.00']
# ['Adidas', 'Ultra Boost DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Men', '10', 'Grey', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Black/Pink', 'Primeknit', '140.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cinder', 'Primeknit', '220.00']
# ['Adidas', 'Ultra Boost DNA', 'Running', 'Women', '8', 'Grey/White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Harden Vol. 5', 'Basketball', 'Women', '8.5', 'Purple', 'Synthetic', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost 4.0', 'Running', 'Men', '11', 'Black', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '9', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Women', '7', 'Black', 'Primeknit', '130.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Casual', 'Men', '11', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Adizero Adios 5', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7.5', 'Grey/Pink', 'Primeknit', '140.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10', 'Black/White', 'Leather', '85.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '9.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '6', 'Blue', 'Primeknit', '180.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10.5', 'White/Gold', 'Leather/Synthetic', '85.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Men', '9.5', 'Black/White', 'Mesh', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '11.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '11.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Women', '8.5', 'Clay Brown', 'Primeknit', '220.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'Cloud White', 'Leather', '80.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '8.5', 'White', 'Primeknit', '180.00']
#
# Brand: Asics
# ['Asics', 'Gel-Kayano 28', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '160.00']
# ['Asics', 'Gel-Nimbus 23', 'Running', 'Women', '8', 'Purple', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '9', 'Grey', 'Mesh/Synthetic', '120.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Purple', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7', 'White', 'Mesh', '160.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '7', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 360', 'Running', 'Men', '11', 'Blue', 'Mesh', '170.00']
# ['Asics', 'GT-2000 9', 'Running', 'Men', '10.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Lyte III NS', 'Casual', 'Women', '8', 'Pink', 'Mesh', '100.00']
# ['Asics', 'Gel-Kayano 28 Lite-Show', 'Running', 'Men', '11', 'Black', 'Mesh', '170.00']
# ['Asics', 'Gel-Venture 8', 'Trail', 'Women', '8.5', 'Blue', 'Mesh', '70.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '7.5', 'White/Grey', 'Mesh/Leather', '180.00']
# ['Asics', 'Gel-Quantum 90 3', 'Running', 'Women', '9', 'Pink', 'Mesh/Synthetic', '90.00']
# ['Asics', 'Gel-Quantum 90 3', 'Running', 'Women', '7.5', 'Black', 'Mesh', '70.00']
# ['Asics', 'Gel-Venture 8', 'Trail', 'Women', '9.5', 'Grey', 'Mesh', '70.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '8', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '9', 'Grey/Green', 'Mesh', '180.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Women', '9', 'Pink', 'Mesh', '75.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10.5', 'Black/Green', 'Mesh', '160.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '8.5', 'Pink/White', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180 5', 'Running', 'Women', '8', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '11', 'Grey', 'Mesh', '120.00']
# ['Asics', 'Gel-Kahana 8', 'Running', 'Men', '8', 'Grey', 'Mesh', '85.00']
# ['Asics', 'GT-1000 9', 'Running', 'Women', '6.5', 'Blue', 'Mesh', '90.00']
# ['Asics', 'Gel-Quantum 180 6', 'Running', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '9', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '8.5', 'White/Black', 'Mesh', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8', 'Black', 'Mesh', '150.00']
# ['Asics', 'GT-2000 10', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '7', 'Black', 'Mesh', '80.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Black/Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '9', 'Black/White', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7.5', 'White/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '9.5', 'Purple', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '8', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Women', '7.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '8', 'Black/Pink', 'Mesh', '80.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '6', 'Pink', 'Mesh/Synthetic', '170.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '12', 'Black', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '9', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8', 'Pink', 'Mesh/Synthetic', '160.00']
# ['Asics', 'GT-2000 10', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 360', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '170.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '11.5', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '7.5', 'Black/Gold', 'Mesh/Synthetic', '90.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '9', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 180 5', 'Running', 'Women', '9', 'Pink/Black', 'Mesh/Synthetic', '120.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7', 'White/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Lyte III', 'Lifestyle', 'Women', '9', 'Black/Grey', 'Leather/Suede', '110.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10.5', 'Black/Red', 'Mesh/Synthetic', '170.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Sonoma 6', 'Trail', 'Women', '6.5', 'Grey', 'Mesh', '75.00']
# ['Asics', 'Gel-Cumulus 22', 'Running', 'Women', '8', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '7', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Contend 7', 'Running', 'Men', '10', 'Blue', 'Mesh', '70.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '9.5', 'Blue/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Black/White', 'Mesh', '140.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Pink', 'Mesh', '150.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '11.5', 'Black/Red', 'Mesh', '120.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '8.5', 'White', 'Mesh', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '9', 'Black/Grey', 'Mesh', '180.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Women', '8.5', 'Purple', 'Mesh/Synthetic', '120.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '7.5', 'White/Grey', 'Mesh/Synthetic', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Black/Pink', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Men', '9', 'Grey/Black', 'Mesh', '75.00']
# ['Asics', 'Gel-Kahana 8', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '85.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Pink', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10.5', 'Black', 'Mesh', '180.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '70.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '11', 'Grey', 'Mesh', '80.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '12', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Men', '11.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '10', 'Blue/Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 9', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '10', 'Grey', 'Mesh', '80.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Blue', 'Mesh', '160.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '7', 'White', 'Mesh', '180.00']
# ['Asics', 'Gel-Venture 8', 'Trail Running', 'Women', '8', 'Grey', 'Mesh', '70.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '9', 'Black/White', 'Mesh/Synthetic', '80.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10', 'Black', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Nimbus Lite 2', 'Running', 'Men', '10', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Nimbus Lite 2', 'Running', 'Men', '10', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Men', '11.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Men', '9', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '7.5', 'White/Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Women', '9', 'Black', 'Mesh', '75.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '150.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Men', '9.5', 'Black', 'Mesh', '160.00']
#
# Brand: Converse
# ['Converse', 'Chuck Taylor', 'Casual', 'Women', '8', 'Navy', 'Canvas', '55.00']
# ['Converse', 'One Star', 'Skate', 'Men', '10', 'Black', 'Suede', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '10', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '8', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'White', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '6', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '8', 'Cream', 'Canvas', '110.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Black', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy/White', 'Canvas', '70.00']
# ['Converse', 'Pro Leather', 'Casual', 'Women', '9.5', 'White/Green', 'Leather', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '6.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Women', '9', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White/Navy', 'Canvas', '70.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'All Star Hi', 'Casual', 'Women', '7', 'Black', 'Canvas', '60.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell Low', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '65.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Men', '12', 'Green', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'Blue', 'Canvas', '65.00']
# ['Converse', 'Pro Leather', 'Casual', 'Men', '9.5', 'White/Green', 'Leather', '80.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Ivory', 'Canvas', '85.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '8.5', 'White', 'Canvas', '110.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Men', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '9', 'White', 'Canvas', '100.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '8', 'Grey', 'Canvas', '85.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Men', '11', 'Black', 'Canvas', '120.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Egret', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '11', 'White', 'Canvas', '75.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '110.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '9.5', 'Purple', 'Canvas', '110.00']
# ['Converse', 'Pro Leather', 'Casual', 'Women', '8.5', 'White/Green', 'Leather', '85.00']
# ['Converse', 'All Star Leather', 'Casual', 'Men', '8.5', 'Black', 'Leather', '65.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Women', '6', 'Red', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'All Star Lift', 'Casual', 'Women', '6.5', 'Black', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'All Star', 'Casual', 'Men', '9', 'Navy', 'Canvas', '55.00']
# ['Converse', 'All Star', 'Casual', 'Women', '8.5', 'Red', 'Canvas', '60.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White', 'Canvas', '70.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '8.5', 'White', 'Leather', '100.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7.5', 'Egret', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8', 'Pink', 'Canvas', '65.00']
# ['Converse', 'All Star Chuck 70', 'Skate', 'Women', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '6.5', 'Sunflower', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell Low Top', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '11.5', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '6.5', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Egret/Black', 'Canvas', '65.00']
# ['Converse', 'Pro Leather', 'Basketball', 'Women', '8.5', 'White', 'Leather', '75.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Skate', 'Women', '6.5', 'White', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '75.00']
# ['Converse', 'Pro Leather', 'Skate', 'Women', '6', 'White', 'Leather', '75.00']
# ['Converse', 'All Star', 'Casual', 'Men', '9', 'Red', 'Canvas', '55.00']
# ['Converse', 'Pro Leather', 'Basketball', 'Women', '8.5', 'White', 'Leather', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Black/White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Red', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Ivory', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '7', 'Green', 'Leather', '100.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'Navy', 'Canvas', '75.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Red', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '12', 'Beige', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '11', 'Grey', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '11.5', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Men', '12', 'Red', 'Leather/Synthetic', '120.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '9.5', 'Black/White', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '9.5', 'Black/White', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9.5', 'Black', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Natural Ivory', 'Canvas', '85.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8', 'Black/White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White', 'Canvas', '70.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '7', 'Red', 'Canvas', '85.00']
#
# Brand: Nike
# ['Nike', 'Air Jordan 1', 'Basketball', 'Men', '10', 'Red/Black', 'Leather', '170.00']
# ['Nike', 'Air Max 270', 'Running', 'Women', '7', 'Pink', 'Mesh', '150.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '10', 'White', 'Leather', '90.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '9', 'Grey', 'Mesh', '150.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Free RN 5.0', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Max 90', 'Lifestyle', 'Women', '6', 'Grey', 'Leather', '120.00']
# ['Nike', 'Blazer Low', 'Lifestyle', 'Women', '7.5', 'White', 'Leather', '85.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '10', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9.5', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'Air Zoom Tempo NEXT% FlyEase', 'Running', 'Women', '8.5', 'White', 'Mesh', '200.00']
# ['Nike', 'React Infinity Run 2', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '160.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'ZoomX Invincible Run', 'Running', 'Men', '11', 'Black', 'Mesh/Synthetic', '180.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '9.5', 'White', 'Leather', '100.00']
# ['Nike', 'KD13', 'Basketball', 'Men', '11', 'Blue', 'Mesh', '150.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '9.5', 'Black/White', 'Flyknit', '160.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '8.5', 'Green', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '10', 'White', 'Leather', '100.00']
# ['Nike', 'Flyknit Trainer', 'Running', 'Men', '10', 'Black/White', 'Flyknit', '150.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '9.5', 'White/Red/Navy', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8.5', 'White/Red', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '12', 'Black', 'Flyknit', '160.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '120.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '12', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '12', 'Black', 'Mesh/Synthetic', '150.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '8.5', 'Green', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'Free RN Flyknit', 'Running', 'Men', '10', 'Blue', 'Knit', '130.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '9', 'Grey', 'Synthetic', '150.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '8', 'Black', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Blazer Mid', 'Casual', 'Women', '7.5', 'Red', 'Leather', '100.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '9', 'Purple', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9', 'Black', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run', 'Running', 'Women', '9.5', 'Grey/Pink', 'Mesh', '160.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', 'Air Max 90', 'Running', 'Men', '8.5', 'White', 'Leather', '120.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9.5', 'Grey', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '9.5', 'White', 'Leather', '100.00']
# ['Nike', 'Air Max 97', 'Running', 'Men', '11.5', 'Black', 'Leather/Synthetic', '170.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Max 95', 'Running', 'Men', '11', 'Grey', 'Synthetic', '170.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '10', 'Blue', 'Flyknit', '160.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '9', 'White/Black', 'Leather', '90.00']
# ['Nike', 'Air Max 90', 'Running', 'Men', '8', 'Black/White', 'Leather/Mesh', '120.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '8', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'Air Max 2090', 'Running', 'Women', '7.5', 'Green', 'Mesh', '150.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '9.5', 'Blue/Black', 'Mesh', '160.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9.5', 'Black/White', 'Flyknit', '160.00']
# ['Nike', 'Zoom Fly 3', 'Running', 'Women', '9', 'Blue', 'Mesh', '160.00']
# ['Nike', "Blazer Mid '77", 'Basketball', 'Men', '11', 'White/Black', 'Leather', '100.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10', 'Blue', 'Mesh/Synthetic', '120.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '9.5', 'Blue/Green', 'Mesh', '160.00']
# ['Nike', 'ZoomX Vaporfly Next%', 'Running', 'Men', '10', 'Black/White', 'Mesh', '250.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10', 'Blue', 'Mesh', '120.00']
# ['Nike', "Blazer Mid '77", 'Skate', 'Men', '9', 'Black/White', 'Leather', '100.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '10.5', 'Green', 'Mesh', '150.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '11', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '12', 'White', 'Leather', '90.00']
# ['Nike', 'Blazer Low', 'Casual', 'Men', '10', 'Black', 'Leather', '85.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '10.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Blue/Pink', 'Mesh', '120.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '11', 'Black', 'Mesh/Synthetic', '160.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Zoom Fly 3', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '8.5', 'White', 'Leather', '90.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Men', '10', 'Black', 'Mesh', '120.00']
# ['Nike', 'SB Dunk Low', 'Skate', 'Men', '9.5', 'Orange', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White/Black', 'Leather', '90.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '11.5', 'Black/White', 'Mesh/Synthetic', '150.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '12', 'White', 'Leather', '90.00']
# ['Nike', 'ZoomX Invincible', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '180.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Epic React Flyknit', 'Running', 'Women', '7.5', 'Grey', 'Flyknit', '150.00']
# ['Nike', 'Air Max 95', 'Running', 'Men', '9', 'Grey', 'Leather/Synthetic', '170.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '8', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '8.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Women', '8.5', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Max 90', 'Casual', 'Women', '7.5', 'Green', 'Leather', '120.00']
# ['Nike', 'Air Max 97', 'Running', 'Men', '11', 'Silver', 'Synthetic/Leather', '170.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8', 'White', 'Leather', '90.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '120.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '6.5', 'Pink', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '12', 'White', 'Leather', '100.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '10.5', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '7', 'Black', 'Flyknit', '160.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8.5', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '120.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '120.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Max 97', 'Running', 'Women', '8', 'Silver', 'Leather/Synthetic', '170.00']
# ['Nike', 'Air Force 1', 'Lifestyle', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '12', 'Black', 'Mesh', '120.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '8.5', 'Pink', 'Flyknit', '160.00']
# ['Nike', 'Air Max 97', 'Running', 'Women', '7.5', 'Silver', 'Leather', '170.00']
#
# Brand: Puma
# ['Puma', 'Future Rider', 'Lifestyle', 'Women', '7.5', 'Pink', 'Mesh', '80.00']
# ['Puma', 'RS-Fast', 'Lifestyle', 'Men', '9.5', 'Yellow', 'Leather/Synthetic', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black', 'Mesh', '80.00']
# ['Puma', 'Future Rider Play', 'Lifestyle', 'Men', '9', 'Black/Red', 'Synthetic', '90.00']
# ['Puma', 'Suede Classic', 'Casual', 'Women', '8.5', 'Beige', 'Suede', '65.00']
# ['Puma', 'Clyde All Pro', 'Basketball', 'Men', '9.5', 'Black/Red', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'Red', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Grey', 'Mesh', '120.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '11', 'Red/White', 'Leather', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Black/Yellow', 'Mesh', '80.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Women', '9.5', 'White', 'Leather', '90.00']
# ['Puma', 'RS-Fast Tech', 'Lifestyle', 'Men', '9.5', 'Black/Red', 'Synthetic', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black/Grey', 'Mesh/Synthetic', '90.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8', 'Red/White', 'Suede', '65.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black/Yellow', 'Mesh', '140.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black', 'Mesh', '100.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9.5', 'Black', 'Leather/Synthetic', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Black', 'Mesh', '80.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'White', 'Leather', '130.00']
# ['Puma', 'Suede Classic', 'Casual', 'Women', '8.5', 'Pink', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black/Blue', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '90.00']
# ['Puma', 'RS-X3 Puzzle', 'Lifestyle', 'Men', '8.5', 'Black/Yellow', 'Synthetic', '110.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black/White', 'Leather/Suede', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'White', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '90.00']
# ['Puma', 'RS-X³', 'Lifestyle', 'Women', '8.5', 'Pink', 'Mesh', '110.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '130.00']
# ['Puma', 'Ralph Sampson', 'Casual', 'Men', '11', 'White/Green', 'Leather', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '8', 'Black', 'Mesh', '90.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Men', '10', 'White', 'Leather/Synthetic', '120.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '6.5', 'Blue', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black', 'Mesh', '80.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'Black', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey/Black', 'Mesh', '90.00']
# ['Puma', 'Wild Rider', 'Lifestyle', 'Men', '11', 'Black/White', 'Suede/Leather', '90.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '11', 'Black', 'Suede', '65.00']
# ['Puma', 'RS-X³ Puzzle', 'Lifestyle', 'Men', '8.5', 'Red', 'Synthetic', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Men', '8.5', 'Black/White', 'Leather', '80.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Ralph Sampson', 'Basketball', 'Men', '11', 'White', 'Leather', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Grey', 'Mesh/Synthetic', '100.00']
# ['Puma', 'Future Rider Play On', 'Lifestyle', 'Women', '9', 'Yellow', 'Synthetic/Textile', '80.00']
# ['Puma', 'Calibrate Rest', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '100.00']
# ['Puma', 'RS-X3', 'Fashion', 'Women', '7.5', 'Pink', 'Leather/Synthetic', '110.00']
# ['Puma', 'Clyde Hardwood', 'Basketball', 'Men', '8', 'Red/Black', 'Leather', '110.00']
# ['Puma', 'Ralph Sampson Mid', 'Basketball', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Grey', 'Mesh', '120.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '10', 'Grey/White', 'Mesh/Synthetic', '120.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'Black/Yellow', 'Leather/Synthetic', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Black/White', 'Mesh', '120.00']
# ['Puma', 'Future Rider', 'Lifestyle', 'Men', '10', 'Blue/Red', 'Synthetic/Mesh', '80.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '12', 'Black/White', 'Leather/Synthetic', '130.00']
# ['Puma', 'RS-X Hard Drive', 'Lifestyle', 'Women', '6.5', 'Silver/White', 'Mesh/Synthetic', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black', 'Mesh', '90.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8', 'Black', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '9.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Cali Sport', 'Fashion', 'Women', '6.5', 'White/Black', 'Leather', '80.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Women', '7', 'Black', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '8', 'Grey/White', 'Mesh', '80.00']
# ['Puma', 'Clyde', 'Retro', 'Men', '8', 'Red', 'Suede', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '11.5', 'White/Black', 'Leather', '130.00']
# ['Puma', 'Clyde Court', 'Basketball', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Puma', 'RS-X', 'Lifestyle', 'Men', '9', 'Black', 'Leather', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '9.5', 'Red/White', 'Suede', '65.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black', 'Mesh', '90.00']
# ['Puma', 'Cell Venom', 'Lifestyle', 'Men', '10', 'Grey', 'Leather', '90.00']
# ['Puma', 'Calibrate Rest', 'Running', 'Women', '8.5', 'Black', 'Mesh', '100.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black', 'Mesh', '90.00']
# ['Puma', 'Suede Classic', 'Fashion', 'Women', '6', 'Black', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7.5', 'Black/White', 'Mesh', '90.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black/Yellow', 'Mesh', '120.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '10.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7', 'Grey', 'Mesh', '90.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'Black', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black/Yellow', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Grey', 'Mesh', '80.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Women', '7.5', 'White', 'Leather/Synthetic', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Blue/White', 'Mesh', '90.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7', 'Black/White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Blue/White', 'Mesh', '90.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7', 'Black/White', 'Leather', '130.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '10', 'Grey', 'Mesh', '120.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Women', '7.5', 'Black', 'Mesh/Suede', '110.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Men', '10', 'Black/White', 'Leather/Synthetic', '80.00']
# ['Puma', 'Suede Classic', 'Lifestyle', 'Men', '8.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7', 'Grey', 'Mesh', '80.00']
# ['Puma', 'Mirage Sport', 'Lifestyle', 'Women', '6', 'Pink', 'Leather', '90.00']
#
# Brand: Fila
# ['Fila', 'Disruptor II', 'Fashion', 'Women', '9', 'White', 'Leather/Synthetic', '65.00']
# ['Fila', 'Ray Tracer', 'Fashion', 'Men', '10', 'Black', 'Synthetic', '70.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '8.5', 'White', 'Leather/Synthetic', '75.00']
# ['Fila', 'Venom', 'Fashion', 'Men', '9.5', 'White/Red', 'Leather/Synthetic', '65.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '11', 'White/Navy', 'Leather', '70.00']
# ['Fila', 'Mindblower', 'Casual', 'Men', '9.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'D-Formation', 'Casual', 'Women', '8.5', 'White', 'Leather', '65.00']
# ['Fila', 'Original Fitness', 'Casual', 'Women', '7', 'White', 'Leather', '60.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9.5', 'White', 'Leather/Synthetic', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Women', '8', 'White/Pink', 'Leather', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'White', 'Synthetic', '75.00']
# ['Fila', 'Original Fitness', 'Fashion', 'Men', '10', 'White', 'Leather', '60.00']
# ['Fila', 'Spaghetti', 'Fashion', 'Men', '8', 'White/Navy', 'Leather/Synthetic', '65.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '9.5', 'White/Navy/Red', 'Leather', '60.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'Grey', 'Leather/Synthetic', '75.00']
# ['Fila', 'F-13', 'Fashion', 'Men', '10', 'White', 'Leather', '70.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '9', 'White/Grey', 'Leather', '85.00']
# ['Fila', 'Spaghetti', 'Basketball', 'Men', '10.5', 'White', 'Leather', '75.00']
# ['Fila', 'Memory Fresh 2', 'Walking', 'Men', '10', 'White', 'Synthetic', '60.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '11', 'Black', 'Leather', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Women', '7', 'Cream', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'White/Black', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9', 'White', 'Leather', '70.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '11', 'White', 'Leather', '65.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '11', 'Black', 'Leather', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7', 'White', 'Leather/Synthetic', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'White/Pink', 'Leather/Synthetic', '65.00']
# ['Fila', 'T1 Mid', 'Casual', 'Men', '11', 'White', 'Leather', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '8', 'White', 'Leather/Synthetic', '65.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '9', 'White', 'Leather', '70.00']
# ['Fila', 'Original Fitness', 'Fashion', 'Women', '7.5', 'White/Navy', 'Leather/Synthetic', '65.00']
# ['Fila', 'Trigate', 'Fashion', 'Men', '9.5', 'White/Navy/Red', 'Synthetic', '60.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '9', 'White/Navy', 'Leather', '60.00']
# ['Fila', 'D-Formation', 'Casual', 'Women', '8.5', 'White', 'Leather', '70.00']
# ['Fila', 'Tracer', 'Fashion', 'Men', '9.5', 'White/Navy', 'Leather/Synthetic', '65.00']
# ['Fila', 'Ray', 'Fashion', 'Men', '11', 'White', 'Synthetic', '65.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '9', 'Green/Orange', 'Leather/Synthetic', '80.00']
# ['Fila', 'Spaghetti', 'Fashion', 'Men', '9.5', 'White/Navy', 'Leather/Synthetic', '75.00']
# ['Fila', 'Original Fitness', 'Fashion', 'Men', '10.5', 'White', 'Leather', '65.00']
# ['Fila', 'Disruptor Low', 'Fashion', 'Men', '9.5', 'White/Navy', 'Synthetic', '60.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'Original Fitness', 'Fashion', 'Men', '11', 'White', 'Leather', '60.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9', 'Grey', 'Synthetic', '70.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '8.5', 'White/Red', 'Leather', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '8.5', 'Red/White', 'Synthetic/Leather', '75.00']
# ['Fila', 'Trigate', 'Fashion', 'Women', '8', 'Pink', 'Synthetic/Leather', '65.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'Pink', 'Leather', '75.00']
# ['Fila', 'D-Formation', 'Fashion', 'Women', '6', 'White/Black', 'Leather/Synthetic', '70.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'White/Red', 'Leather', '75.00']
# ['Fila', 'Trailblazer', 'Hiking', 'Women', '8', 'Beige', 'Leather/Synthetic', '85.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'White/Red', 'Leather', '75.00']
# ['Fila', 'Original Fitness', 'Casual', 'Women', '8.5', 'White', 'Leather', '60.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '11', 'White/Navy/Red', 'Leather', '70.00']
# ['Fila', 'Trigate', 'Running', 'Men', '10', 'Black/White', 'Mesh/Synthetic', '65.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '9.5', 'White/Red', 'Leather/Synthetic', '70.00']
# ['Fila', 'Venom', 'Fashion', 'Men', '8.5', 'White/Red/Navy', 'Leather/Synthetic', '65.00']
# ...
# ['Reebok', 'Floatride Energy 3', 'Running', 'Women', '6.5', 'Black', 'Mesh', '100.00']
# ['Reebok', 'Nano X', 'Crossfit', 'Men', '10.5', 'Black', 'Synthetic', '130.00']
# ['Reebok', 'Club C Revenge', 'Casual', 'Women', '8.5', 'Pink/White', 'Leather', '80.00']
# ['Reebok', 'Nano X', 'Crossfit', 'Men', '10.5', 'Black', 'Synthetic', '130.00']
# ['Reebok', 'Club C Revenge', 'Casual', 'Women', '8.5', 'Pink/White', 'Leather', '80.00']
# ['Reebok', 'Nano X1', 'Crossfit', 'Men', '9.5', 'Grey', 'Knit', '130.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '10', 'Grey', 'Nylon', '65.00']
# ['Reebok', 'Nano X', 'Training', 'Men', '9.5', 'Black/Red', 'Synthetic/Mesh', '130.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '10.5', 'Collegiate Navy', 'Nylon/Suede', '65.00']
# ['Reebok', 'Nano X', 'Crossfit', 'Men', '10.5', 'Black', 'Mesh', '130.00']
# ['Reebok', 'Aztrek 96', 'Casual', 'Women', '7.5', 'Yellow', 'Leather/Synthetic', '90.00']
#
# Brand: Skechers
# ['Skechers', 'Go Run Razor 3', 'Running', 'Men', '9', 'Black', 'Mesh', '110.00']
# ['Skechers', 'Arch Fit', 'Walking', 'Women', '7.5', 'Grey', 'Mesh', '70.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '7', 'Black', 'Synthetic', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '7.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Dynamight 2.0', 'Training', 'Women', '9', 'Black', 'Mesh', '50.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '8.5', 'Black', 'Mesh', '90.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Men', '10', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7', 'Black', 'Mesh', '75.00']
# ['Skechers', 'Summits - Quick Getaway', 'Walking', 'Men', '9', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Max Cushioning Elite', 'Walking', 'Women', '8', 'Navy', 'Mesh', '80.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo Pep', 'Running', 'Women', '8.5', 'Black/White', 'Mesh', '55']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '90.00']
# ['Skechers', 'Equalizer 4.0', 'Training', 'Women', '8.5', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '7', 'Grey/Pink', 'Mesh', '105.00']
# ['Skechers', 'Uno Bold Move', 'Casual', 'Women', '8.5', 'Black/White', 'Synthetic', '70.00']
# ['Skechers', 'Energy Burst', 'Running', 'Women', '8', 'Black', 'Mesh', '70.00']
# ['Skechers', 'Equalizer 4.0', 'Walking', 'Women', '7', 'Grey', 'Mesh', '60.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '9.5', 'White/Black', 'Leather', '70.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Women', '9', 'Black', 'Mesh', '75.00']
# ['Skechers', 'Equalizer 4.0', 'Training', 'Women', '8.5', 'Black', 'Knit', '70.00']
# ['Skechers', 'Arch Fit Refine', 'Walking', 'Women', '6.5', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'GOrun Mojo 2.0', 'Running', 'Men', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '11', 'Black', 'Mesh', '85.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7.5', 'Black', 'Mesh', '90.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '8', 'White', 'Leather', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '9', 'Grey', 'Mesh', '65.00']
# ['Skechers', 'Summits', 'Walking', 'Women', '7.5', 'Black/Pink', 'Mesh', '60.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '90.00']
# ['Skechers', 'Equalizer 4.0', 'Walking', 'Men', '12', 'Navy', 'Mesh', '65.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '6.5', 'Black/White', 'Synthetic', '65.00']
# ['Skechers', 'Ultra Flex 2.0', 'Walking', 'Women', '7.5', 'Navy/White', 'Mesh', '60.00']
# ['Skechers', 'Go Walk Joy', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '54.99']
# ['Skechers', 'Go Run 600', 'Running', 'Women', '6', 'Pink', 'Mesh', '60.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Women', '7.5', 'Black', 'Mesh', '70.00']
# ['Skechers', 'Summits - Quick Lapse', 'Walking', 'Women', '8', 'Black/Pink', 'Mesh', '60.00']
# ['Skechers', "D'Lites", 'Lifestyle', 'Women', '8.5', 'White', 'Leather/Synthetic', '65.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Women', '7.5', 'Grey', 'Knit', '65.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Navy', 'Mesh/Synthetic', '110.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Men', '11', 'Grey', 'Mesh', '90.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '10', 'Black', 'Mesh', '65.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '7.5', 'Black', 'Leather/Synthetic', '60.00']
# ['Skechers', 'Summits', 'Training', 'Men', '11', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Energy Wave Linxe', 'Walking', 'Women', '8', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo 2.0', 'Running', 'Men', '9', 'Black', 'Mesh', '55.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Women', '9', 'Grey/Pink', 'Knit', '70.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Black', 'Mesh', '100.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '12', 'White', 'Synthetic/Leather', '65.00']
# ['Skechers', 'Solar Fuse', 'Walking', 'Women', '8', 'Grey', 'Mesh', '70.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '8', 'Navy', 'Mesh', '85.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '7', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '9.5', 'Grey/Pink', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo Pep', 'Running', 'Men', '8.5', 'Black', 'Mesh', '70.00']
# ['Skechers', 'Flex Appeal 4.0', 'Training', 'Men', '8.5', 'Grey/Orange', 'Knit', '70.00']
# ['Skechers', 'Go Run Ride 8', 'Running', 'Women', '7.5', 'Black/Pink', 'Mesh', '90.00']
# ['Skechers', 'Summits', 'Walking', 'Women', '9', 'Black/Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7.5', 'Black/Pink', 'Mesh', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '9', 'Charcoal', 'Mesh', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'Stamina', 'Training', 'Men', '9', 'Black', 'Leather', '65.00']
# ['Skechers', 'Uno Bold', 'Lifestyle', 'Women', '7.5', 'Pink/White', 'Synthetic', '70.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Grey/Pink', 'Mesh', '90.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '10.5', 'Black', 'Leather', '60.00']
# ['Skechers', 'Summits', 'Walking', 'Men', '12', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'GOwalk 5', 'Walking', 'Men', '9', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '90.00']
# ['Skechers', 'Summits - New World', 'Walking', 'Men', '10', 'Black', 'Mesh', '59.00']
# ['Skechers', 'GOrun Razor Excess', 'Running', 'Men', '9', 'Black/Yellow', 'Mesh', '125.00']
# ['Skechers', 'Go Walk 6', 'Walking', 'Men', '10.5', 'Black/Grey', 'Mesh', '60.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Men', '9.5', 'Grey', 'Knit', '70.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Men', '9.5', 'Black', 'Mesh', '80.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'GOrun 7+', 'Running', 'Women', '8', 'Black/Pink', 'Mesh', '95.00']
# ['Skechers', 'Max Cushioning Premier', 'Walking', 'Women', '7', 'Grey', 'Mesh', '80.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Men', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 6', 'Walking', 'Men', '9.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Men', '8', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Men', '8', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7.5', 'Navy', 'Mesh', '90.00']
# ['Skechers', "D'Lites", 'Walking', 'Men', '11', 'White', 'Leather', '65.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '6.5', 'Black/White', 'Mesh', '90.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '11', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Summits', 'Training', 'Men', '8', 'Grey', 'Mesh', '55.00']
#
# Brand: Vans
# ['Vans', 'Old Skool', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Authentic', 'Skate', 'Women', '6', 'White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '7', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'White', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black', 'Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6', 'Black', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Green', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas', '65.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Green', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '6.5', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Era 95 DX', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Pink/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '6', 'Red/White', 'Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Pink', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Checkerboard', 'Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas/Leather', '70.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '10.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Black', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Canvas/Suede', '65.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '8', 'Black/White Checkerboard', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Yellow', 'Suede', '65.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '8', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '7', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '8.5', 'Red', 'Canvas', '55.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '9.5', 'Purple', 'Canvas/Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '9.5', 'Checkerboard Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Red', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '8.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '8', 'Multi-color', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Pink', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Yellow', 'Canvas/Suede', '65.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '7.5', 'Pink', 'Suede/Canvas', '65.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Red', 'Canvas/Suede', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '9', 'Checkerboard Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '8', 'True White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9.5', 'Blue/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '10.5', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Pink/White', 'Canvas', '65.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '8.5', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Red', 'Suede', '65.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '6.5', 'Blue/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Purple', 'Suede/Canvas', '65.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '6.5', 'Checkerboard', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9.5', 'Red', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '8', 'Grey', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '10', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '8.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Canvas/Suede', '65.00']
# ['Vans', 'Era', 'Skate', 'Men', '8', 'Navy', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '8', 'Red/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '9', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Red/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Era', 'Skate', 'Women', '6', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '50.00']

# %%
# Sort the grouped data by price in descending order
sorted_grouped_by_price_rdd = grouped_by_brand_rdd.mapValues(lambda rows: sorted(rows, key=lambda x: float(x[7]), reverse=True))

# Show the sorted grouped data for a few brands
for brand, rows in sorted_grouped_by_price_rdd.collect():
    print(f"Brand: {brand}")
    for row in rows:
        print(row)
    print()
# Out:
# Brand: Adidas
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Men', '10', 'Black', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Men', '9', 'Zebra', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Women', '6.5', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cream White', 'Primeknit/Synthetic', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '7', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '10', 'Cream', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Women', '6.5', 'Cloud White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '7.5', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350', 'Fashion', 'Women', '8', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '11', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '9', 'Natural', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Men', '10', 'Grey', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Fashion', 'Women', '8.5', 'Cinder', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Lifestyle', 'Men', '9', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350 V2', 'Casual', 'Men', '11', 'Cream White', 'Primeknit', '220.00']
# ['Adidas', 'Yeezy Boost 350', 'Lifestyle', 'Women', '8.5', 'Clay Brown', 'Primeknit', '220.00']
# ['Adidas', 'Ultra Boost 21', 'Running', 'Men', '9.5', 'Black', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 5.0 DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '8', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 6.0', 'Running', 'Women', '7.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 4.0', 'Running', 'Women', '7', 'Blue', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 5.0 DNA', 'Running', 'Men', '9', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 20', 'Running', 'Men', '9.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '6.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 6.0', 'Running', 'Women', '7', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Ultra Boost DNA', 'Running', 'Women', '8.5', 'Grey', 'Primeknit', '180.00']
# ['Adidas', 'Ultra Boost DNA', 'Running', 'Women', '8', 'Grey/White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost 4.0', 'Running', 'Men', '11', 'Black', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '9.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Women', '6', 'Blue', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '11.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '11.5', 'Black/White', 'Primeknit', '180.00']
# ['Adidas', 'Ultraboost DNA', 'Running', 'Men', '8.5', 'White', 'Primeknit', '180.00']
# ['Adidas', 'Adizero Adios 5', 'Running', 'Women', '7.5', 'Blue', 'Mesh', '170.00']
# ['Adidas', 'ZX 2K Boost', 'Casual', 'Women', '7.5', 'White/Pink', 'Mesh/Synthetic', '150.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Black/Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '9', 'Black', 'Knit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Men', '8.5', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Men', '11.5', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Pink', 'Knit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Black/Pink', 'Knit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Fashion', 'Women', '7', 'Grey', 'Knit/Synthetic', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8.5', 'Black/Pink', 'Knit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'White/Black', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8.5', 'Grey/Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Black/Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink', 'Primeknit', '140.00']
# ['Adidas', 'Adizero Adios 5', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '140.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7.5', 'Grey/Pink', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Grey', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black', 'Primeknit', '140.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '8.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Men', '9', 'Black/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Women', '8.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1 V2', 'Casual', 'Women', '6.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '6', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7', 'Black/Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Grey', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Harden Vol. 5', 'Basketball', 'Women', '8.5', 'Grey', 'Textile', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Black/Grey', 'Primeknit', '130.00']
# ['Adidas', 'Harden Vol. 5', 'Basketball', 'Women', '8.5', 'Purple', 'Synthetic', '130.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Women', '7', 'Black', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Running', 'Women', '7', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Casual', 'Men', '9.5', 'Black/White', 'Mesh', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '8', 'Pink/White', 'Primeknit', '130.00']
# ['Adidas', 'NMD_R1', 'Lifestyle', 'Women', '7.5', 'Pink', 'Primeknit', '130.00']
# ['Adidas', 'Adizero Boston 9', 'Running', 'Women', '6.5', 'Black', 'Mesh', '120.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'Black/White', 'Leather', '85.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '9.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '8.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10', 'Black/White', 'Leather', '85.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10.5', 'White/Gold', 'Leather/Synthetic', '85.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '85.00']
# ['Adidas', 'Stan Smith', 'Casual', 'Men', '9', 'White/Green', 'Leather', '80.00']
# ['Adidas', 'Harden Stepback', 'Basketball', 'Men', '12', 'Grey', 'Synthetic', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '8.5', 'Black/White', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '10', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Men', '11', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '8.5', 'White/Black', 'Leather', '80.00']
# ['Adidas', 'Superstar', 'Casual', 'Women', '7.5', 'Cloud White', 'Leather', '80.00']
# ['Adidas', 'Adilette Cloudfoam', 'Slides', 'Women', '6', 'Black', 'Synthetic', '35.00']
# ['Adidas', 'Adilette Comfort', 'Slides', 'Women', '6', 'Black', 'Synthetic', '35.00']
# ['Adidas', 'Adilette Shower', 'Slides', 'Women', '6', 'Pink', 'Synthetic', '25.00']
#
# Brand: Asics
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '7.5', 'White/Grey', 'Mesh/Leather', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '9', 'Grey/Green', 'Mesh', '180.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '8.5', 'White/Black', 'Mesh', '180.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '8.5', 'White', 'Mesh', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '9', 'Black/Grey', 'Mesh', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '7.5', 'White/Grey', 'Mesh/Synthetic', '180.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10.5', 'Black', 'Mesh', '180.00']
# ['Asics', 'Gel-Kinsei OG', 'Running', 'Women', '7', 'White', 'Mesh', '180.00']
# ['Asics', 'Gel-Quantum 360', 'Running', 'Men', '11', 'Blue', 'Mesh', '170.00']
# ['Asics', 'Gel-Kayano 28 Lite-Show', 'Running', 'Men', '11', 'Black', 'Mesh', '170.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '6', 'Pink', 'Mesh/Synthetic', '170.00']
# ['Asics', 'Gel-Quantum 360', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '170.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10.5', 'Black/Red', 'Mesh/Synthetic', '170.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Purple', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7', 'White', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10.5', 'Black/Green', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '9', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7.5', 'White/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '12', 'Black', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8', 'Pink', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '11.5', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '9', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 28', 'Running', 'Women', '7', 'White/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '7', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '9.5', 'Blue/Pink', 'Mesh', '160.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Black/Pink', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '12', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Women', '8.5', 'Blue', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '10', 'Black', 'Mesh/Synthetic', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano 27', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Men', '9', 'Grey', 'Mesh', '160.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Men', '9.5', 'Black', 'Mesh', '160.00']
# ['Asics', 'Gel-Nimbus 23', 'Running', 'Women', '8', 'Purple', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '9', 'Black/White', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Pink', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Women', '8.5', 'Pink', 'Mesh', '150.00']
# ['Asics', 'Gel-Nimbus Lite 2', 'Running', 'Men', '10', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Nimbus Lite 2', 'Running', 'Men', '10', 'Black', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 360 6', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '150.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Black/White', 'Mesh', '140.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '9', 'Grey', 'Mesh/Synthetic', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '7', 'Blue', 'Mesh', '120.00']
# ['Asics', 'GT-2000 9', 'Running', 'Men', '10.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '8', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '8.5', 'Pink/White', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180 5', 'Running', 'Women', '8', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '11', 'Grey', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180 6', 'Running', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '9', 'Black/Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '9.5', 'Purple', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Women', '8', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Women', '7.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '9', 'Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 10', 'Running', 'Men', '9.5', 'Grey', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180 5', 'Running', 'Women', '9', 'Pink/Black', 'Mesh/Synthetic', '120.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Women', '7.5', 'Blue', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 22', 'Running', 'Women', '8', 'Pink', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '11.5', 'Black/Red', 'Mesh', '120.00']
# ['Asics', 'Gel-Kayano Lite', 'Running', 'Women', '8.5', 'Purple', 'Mesh/Synthetic', '120.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Men', '11.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Men', '10', 'Blue/Black', 'Mesh', '120.00']
# ['Asics', 'GT-2000 9', 'Running', 'Men', '9.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Quantum 180', 'Running', 'Men', '11.5', 'Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Cumulus 23', 'Running', 'Women', '7.5', 'White/Black', 'Mesh', '120.00']
# ['Asics', 'Gel-Lyte III', 'Lifestyle', 'Women', '9', 'Black/Grey', 'Leather/Suede', '110.00']
# ['Asics', 'Gel-Lyte III NS', 'Casual', 'Women', '8', 'Pink', 'Mesh', '100.00']
# ['Asics', 'Gel-Quantum 90 3', 'Running', 'Women', '9', 'Pink', 'Mesh/Synthetic', '90.00']
# ['Asics', 'GT-1000 9', 'Running', 'Women', '6.5', 'Blue', 'Mesh', '90.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '7.5', 'Black/Gold', 'Mesh/Synthetic', '90.00']
# ['Asics', 'Gel-Kahana 8', 'Running', 'Men', '8', 'Grey', 'Mesh', '85.00']
# ['Asics', 'Gel-Kahana 8', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '85.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '7', 'Black', 'Mesh', '80.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Women', '8', 'Black/Pink', 'Mesh', '80.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '11', 'Grey', 'Mesh', '80.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '10', 'Grey', 'Mesh', '80.00']
# ['Asics', 'Gel-Quantum 90', 'Running', 'Men', '9', 'Black/White', 'Mesh/Synthetic', '80.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Women', '9', 'Pink', 'Mesh', '75.00']
# ['Asics', 'Gel-Sonoma 6', 'Trail', 'Women', '6.5', 'Grey', 'Mesh', '75.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Men', '9', 'Grey/Black', 'Mesh', '75.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Women', '9', 'Black', 'Mesh', '75.00']
# ['Asics', 'Gel-Venture 8', 'Trail', 'Women', '8.5', 'Blue', 'Mesh', '70.00']
# ['Asics', 'Gel-Quantum 90 3', 'Running', 'Women', '7.5', 'Black', 'Mesh', '70.00']
# ['Asics', 'Gel-Venture 8', 'Trail', 'Women', '9.5', 'Grey', 'Mesh', '70.00']
# ['Asics', 'Gel-Contend 7', 'Running', 'Men', '10', 'Blue', 'Mesh', '70.00']
# ['Asics', 'Gel-Excite 8', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '70.00']
# ['Asics', 'Gel-Venture 8', 'Trail Running', 'Women', '8', 'Grey', 'Mesh', '70.00']
#
# Brand: Converse
# ['Converse', 'All Star Pro BB', 'Basketball', 'Men', '11', 'Black', 'Canvas', '120.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Men', '12', 'Red', 'Leather/Synthetic', '120.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '8', 'Cream', 'Canvas', '110.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '8.5', 'White', 'Canvas', '110.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '110.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '9.5', 'Purple', 'Canvas', '110.00']
# ['Converse', 'Run Star Hike', 'Casual', 'Women', '9', 'White', 'Canvas', '100.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '8.5', 'White', 'Leather', '100.00']
# ['Converse', 'All Star Pro BB', 'Basketball', 'Women', '7', 'Green', 'Leather', '100.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '8', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'White', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Women', '9', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Men', '12', 'Green', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Ivory', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Men', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '8', 'Grey', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Egret', 'Canvas', '85.00']
# ['Converse', 'Pro Leather', 'Casual', 'Women', '8.5', 'White/Green', 'Leather', '85.00']
# ['Converse', 'Chuck 70 High', 'Casual', 'Women', '6', 'Red', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7.5', 'Egret', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'All Star Chuck 70', 'Skate', 'Women', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '6.5', 'Sunflower', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '11.5', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '6.5', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Pink', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Skate', 'Women', '6.5', 'White', 'Canvas', '85.00']
# ['Converse', 'Pro Leather', 'Basketball', 'Women', '8.5', 'White', 'Leather', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Red', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Ivory', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '9', 'Red', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '12', 'Beige', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '11', 'Grey', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '8.5', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9', 'Cream', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '11.5', 'Yellow', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '9.5', 'Black/White', 'Canvas', '85.00']
# ['Converse', 'Chuck 70 High Top', 'Casual', 'Men', '9.5', 'Black/White', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '9.5', 'Black', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Women', '7', 'Natural Ivory', 'Canvas', '85.00']
# ['Converse', 'Chuck 70', 'Casual', 'Men', '7', 'Red', 'Canvas', '85.00']
# ['Converse', 'Pro Leather', 'Casual', 'Men', '9.5', 'White/Green', 'Leather', '80.00']
# ['Converse', 'One Star', 'Skate', 'Men', '10', 'Black', 'Suede', '75.00']
# ['Converse', 'Pro Leather', 'Casual', 'Women', '9.5', 'White/Green', 'Leather', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '11', 'White', 'Canvas', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '75.00']
# ['Converse', 'Pro Leather', 'Basketball', 'Women', '8.5', 'White', 'Leather', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '75.00']
# ['Converse', 'Pro Leather', 'Skate', 'Women', '6', 'White', 'Leather', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'Navy', 'Canvas', '75.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy/White', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White/Navy', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'White', 'Canvas', '70.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '10', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '6', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '6.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell Low', 'Casual', 'Women', '7.5', 'Pink', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'Blue', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'All Star Leather', 'Casual', 'Men', '8.5', 'Black', 'Leather', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'All Star Lift', 'Casual', 'Women', '6.5', 'Black', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8', 'Pink', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell Low Top', 'Casual', 'Women', '7', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Egret/Black', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'Black/White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '7.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '8.5', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9', 'Navy', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Men', '9.5', 'White', 'Canvas', '65.00']
# ['Converse', 'Jack Purcell', 'Casual', 'Women', '8', 'Black/White', 'Canvas', '65.00']
# ['Converse', 'All Star Hi', 'Casual', 'Women', '7', 'Black', 'Canvas', '60.00']
# ['Converse', 'All Star', 'Casual', 'Women', '8.5', 'Red', 'Canvas', '60.00']
# ['Converse', 'Chuck Taylor', 'Casual', 'Women', '8', 'Navy', 'Canvas', '55.00']
# ['Converse', 'All Star', 'Casual', 'Men', '9', 'Navy', 'Canvas', '55.00']
# ['Converse', 'All Star', 'Casual', 'Men', '9', 'Red', 'Canvas', '55.00']
#
# Brand: Nike
# ['Nike', 'ZoomX Vaporfly Next%', 'Running', 'Men', '10', 'Black/White', 'Mesh', '250.00']
# ['Nike', 'Air Zoom Tempo NEXT% FlyEase', 'Running', 'Women', '8.5', 'White', 'Mesh', '200.00']
# ['Nike', 'ZoomX Invincible Run', 'Running', 'Men', '11', 'Black', 'Mesh/Synthetic', '180.00']
# ['Nike', 'ZoomX Invincible', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '180.00']
# ['Nike', 'Air Jordan 1', 'Basketball', 'Men', '10', 'Red/Black', 'Leather', '170.00']
# ['Nike', 'Air Max 97', 'Running', 'Men', '11.5', 'Black', 'Leather/Synthetic', '170.00']
# ['Nike', 'Air Max 95', 'Running', 'Men', '11', 'Grey', 'Synthetic', '170.00']
# ['Nike', 'Air Max 95', 'Running', 'Men', '9', 'Grey', 'Leather/Synthetic', '170.00']
# ['Nike', 'Air Max 97', 'Running', 'Men', '11', 'Silver', 'Synthetic/Leather', '170.00']
# ['Nike', 'Air Max 97', 'Running', 'Women', '8', 'Silver', 'Leather/Synthetic', '170.00']
# ['Nike', 'Air Max 97', 'Running', 'Women', '7.5', 'Silver', 'Leather', '170.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9.5', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run 2', 'Running', 'Women', '7.5', 'Grey', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '9.5', 'Black/White', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '12', 'Black', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '8', 'Black', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '9', 'Purple', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9', 'Black', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run', 'Running', 'Women', '9.5', 'Grey/Pink', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '10', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '8', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '9.5', 'Blue/Black', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Men', '9.5', 'Black/White', 'Flyknit', '160.00']
# ['Nike', 'Zoom Fly 3', 'Running', 'Women', '9', 'Blue', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '9.5', 'Blue/Green', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '11', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run', 'Running', 'Men', '11', 'Black', 'Mesh/Synthetic', '160.00']
# ['Nike', 'Zoom Fly 3', 'Running', 'Men', '10', 'Black', 'Mesh', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '8', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '6.5', 'Pink', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Men', '10.5', 'Blue', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit', 'Running', 'Women', '7', 'Black', 'Flyknit', '160.00']
# ['Nike', 'React Infinity Run Flyknit 2', 'Running', 'Women', '8.5', 'Pink', 'Flyknit', '160.00']
# ['Nike', 'Air Max 270', 'Running', 'Women', '7', 'Pink', 'Mesh', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '9', 'Grey', 'Mesh', '150.00']
# ['Nike', 'KD13', 'Basketball', 'Men', '11', 'Blue', 'Mesh', '150.00']
# ['Nike', 'Flyknit Trainer', 'Running', 'Men', '10', 'Black/White', 'Flyknit', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '12', 'Black', 'Mesh/Synthetic', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '9', 'Grey', 'Synthetic', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Women', '7.5', 'Green', 'Mesh', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '10.5', 'Green', 'Mesh', '150.00']
# ['Nike', 'Air Max 2090', 'Running', 'Men', '11.5', 'Black/White', 'Mesh/Synthetic', '150.00']
# ['Nike', 'Epic React Flyknit', 'Running', 'Women', '7.5', 'Grey', 'Flyknit', '150.00']
# ['Nike', 'Free RN Flyknit', 'Running', 'Men', '10', 'Blue', 'Knit', '130.00']
# ['Nike', 'Air Max 90', 'Lifestyle', 'Women', '6', 'Grey', 'Leather', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '12', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Max 90', 'Running', 'Men', '8.5', 'White', 'Leather', '120.00']
# ['Nike', 'Air Max 90', 'Running', 'Men', '8', 'Black/White', 'Leather/Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10', 'Blue', 'Mesh/Synthetic', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '10', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Blue/Pink', 'Mesh', '120.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Men', '10', 'Black', 'Mesh', '120.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Women', '8.5', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Max 90', 'Casual', 'Women', '7.5', 'Green', 'Leather', '120.00']
# ['Nike', 'Zoom Pegasus 38', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '120.00']
# ['Nike', 'Air Zoom Pegasus 38', 'Running', 'Men', '12', 'Black', 'Mesh', '120.00']
# ['Nike', 'Free RN 5.0', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '9.5', 'White', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '8.5', 'Green', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '10', 'White', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '9.5', 'White/Red/Navy', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '8.5', 'Green', 'Leather', '100.00']
# ['Nike', 'Blazer Mid', 'Casual', 'Women', '7.5', 'Red', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '9.5', 'White', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Basketball', 'Men', '11', 'White/Black', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Skate', 'Men', '9', 'Black/White', 'Leather', '100.00']
# ['Nike', 'SB Dunk Low', 'Skate', 'Men', '9.5', 'Orange', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '10', 'White/Black', 'Leather', '100.00']
# ['Nike', "Blazer Mid '77", 'Casual', 'Men', '12', 'White', 'Leather', '100.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '10', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '10', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8.5', 'White/Red', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9.5', 'Grey', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '9', 'White/Black', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '12', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '10.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1 Low', 'Casual', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Basketball', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '8.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White/Black', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '12', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '8.5', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Women', '8.5', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', "Air Force 1 '07", 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Lifestyle', 'Men', '11', 'White', 'Leather', '90.00']
# ['Nike', 'Air Force 1', 'Casual', 'Men', '9', 'White', 'Leather', '90.00']
# ['Nike', 'Blazer Low', 'Lifestyle', 'Women', '7.5', 'White', 'Leather', '85.00']
# ['Nike', 'Blazer Low', 'Casual', 'Men', '10', 'Black', 'Leather', '85.00']
#
# Brand: Puma
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black/Yellow', 'Mesh', '140.00']
# ['Puma', 'Clyde All Pro', 'Basketball', 'Men', '9.5', 'Black/Red', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'Red', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9.5', 'Black', 'Leather/Synthetic', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black/White', 'Leather/Suede', '130.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10', 'Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'Black/Yellow', 'Leather/Synthetic', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '12', 'Black/White', 'Leather/Synthetic', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '11.5', 'White/Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '10.5', 'Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7.5', 'White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '9', 'Black', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7', 'Black/White', 'Leather', '130.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Women', '7', 'Black/White', 'Leather', '130.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Grey', 'Mesh', '120.00']
# ['Puma', 'Clyde All-Pro', 'Basketball', 'Men', '11', 'Red/White', 'Leather', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black/Blue', 'Mesh', '120.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Men', '10', 'White', 'Leather/Synthetic', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '6.5', 'Blue', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Grey', 'Mesh', '120.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '10', 'Grey/White', 'Mesh/Synthetic', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Black/White', 'Mesh', '120.00']
# ['Puma', 'RS-X Hard Drive', 'Lifestyle', 'Women', '6.5', 'Silver/White', 'Mesh/Synthetic', '120.00']
# ['Puma', 'Clyde Court', 'Basketball', 'Men', '11', 'Black', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black/Yellow', 'Mesh', '120.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black/Yellow', 'Mesh', '120.00']
# ['Puma', 'Calibrate', 'Running', 'Men', '10', 'Grey', 'Mesh', '120.00']
# ['Puma', 'RS-Fast', 'Lifestyle', 'Men', '9.5', 'Yellow', 'Leather/Synthetic', '110.00']
# ['Puma', 'RS-Fast Tech', 'Lifestyle', 'Men', '9.5', 'Black/Red', 'Synthetic', '110.00']
# ['Puma', 'RS-X3 Puzzle', 'Lifestyle', 'Men', '8.5', 'Black/Yellow', 'Synthetic', '110.00']
# ['Puma', 'RS-X³', 'Lifestyle', 'Women', '8.5', 'Pink', 'Mesh', '110.00']
# ['Puma', 'RS-X³ Puzzle', 'Lifestyle', 'Men', '8.5', 'Red', 'Synthetic', '110.00']
# ['Puma', 'RS-X3', 'Fashion', 'Women', '7.5', 'Pink', 'Leather/Synthetic', '110.00']
# ['Puma', 'Clyde Hardwood', 'Basketball', 'Men', '8', 'Red/Black', 'Leather', '110.00']
# ['Puma', 'RS-X', 'Lifestyle', 'Men', '9', 'Black', 'Leather', '110.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Women', '7.5', 'White', 'Leather/Synthetic', '110.00']
# ['Puma', 'RS-2K', 'Lifestyle', 'Women', '7.5', 'Black', 'Mesh/Suede', '110.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black', 'Mesh', '100.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Grey', 'Mesh/Synthetic', '100.00']
# ['Puma', 'Calibrate Rest', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '100.00']
# ['Puma', 'Calibrate Rest', 'Running', 'Women', '8.5', 'Black', 'Mesh', '100.00']
# ['Puma', 'Future Rider Play', 'Lifestyle', 'Men', '9', 'Black/Red', 'Synthetic', '90.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Women', '9.5', 'White', 'Leather', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black/Grey', 'Mesh/Synthetic', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Blue', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'White', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '8', 'Black', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Grey/Black', 'Mesh', '90.00']
# ['Puma', 'Wild Rider', 'Lifestyle', 'Men', '11', 'Black/White', 'Suede/Leather', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Puma', 'Ralph Sampson Mid', 'Basketball', 'Men', '9.5', 'White', 'Leather', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10', 'Black', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black', 'Mesh', '90.00']
# ['Puma', 'Cell Venom', 'Lifestyle', 'Men', '10', 'Grey', 'Leather', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7.5', 'Black/White', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7', 'Grey', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Blue/White', 'Mesh', '90.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Blue/White', 'Mesh', '90.00']
# ['Puma', 'Mirage Sport', 'Lifestyle', 'Women', '6', 'Pink', 'Leather', '90.00']
# ['Puma', 'Future Rider', 'Lifestyle', 'Women', '7.5', 'Pink', 'Mesh', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '9.5', 'Black', 'Mesh', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '10.5', 'Black/Yellow', 'Mesh', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '11', 'Black', 'Mesh', '80.00']
# ['Puma', 'Ralph Sampson', 'Casual', 'Men', '11', 'White/Green', 'Leather', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Men', '8.5', 'Black', 'Mesh', '80.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Men', '8.5', 'Black/White', 'Leather', '80.00']
# ['Puma', 'Ralph Sampson', 'Basketball', 'Men', '11', 'White', 'Leather', '80.00']
# ['Puma', 'Future Rider Play On', 'Lifestyle', 'Women', '9', 'Yellow', 'Synthetic/Textile', '80.00']
# ['Puma', 'Future Rider', 'Lifestyle', 'Men', '10', 'Blue/Red', 'Synthetic/Mesh', '80.00']
# ['Puma', 'Cali Sport', 'Fashion', 'Women', '6.5', 'White/Black', 'Leather', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '8', 'Grey/White', 'Mesh', '80.00']
# ['Puma', 'Clyde', 'Retro', 'Men', '8', 'Red', 'Suede', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '9', 'Grey', 'Mesh', '80.00']
# ['Puma', 'Cali Sport', 'Lifestyle', 'Men', '10', 'Black/White', 'Leather/Synthetic', '80.00']
# ['Puma', 'Calibrate Runner', 'Running', 'Women', '7', 'Grey', 'Mesh', '80.00']
# ['Puma', 'Suede Classic', 'Casual', 'Women', '8.5', 'Beige', 'Suede', '65.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8', 'Red/White', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Casual', 'Women', '8.5', 'Pink', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '11', 'Black', 'Suede', '65.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8', 'Black', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '9.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Women', '7', 'Black', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '9.5', 'Red/White', 'Suede', '65.00']
# ['Puma', 'Suede Classic+', 'Casual', 'Men', '8.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Fashion', 'Women', '6', 'Black', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Casual', 'Men', '10.5', 'Black/White', 'Suede', '65.00']
# ['Puma', 'Suede Classic', 'Lifestyle', 'Men', '8.5', 'Black/White', 'Suede', '65.00']
#
# Brand: Fila
# ['Fila', 'Grant Hill 2', 'Basketball', 'Women', '8', 'White/Navy', 'Leather', '95.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '9', 'White/Grey', 'Leather', '85.00']
# ['Fila', 'Trailblazer', 'Hiking', 'Women', '8', 'Beige', 'Leather/Synthetic', '85.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '9', 'Green/Orange', 'Leather/Synthetic', '80.00']
# ['Fila', 'F-13', 'Casual', 'Women', '9', 'White', 'Leather', '80.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '8.5', 'Pink', 'Leather', '80.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '8.5', 'White', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Casual', 'Men', '9.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9.5', 'White', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'White', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'Grey', 'Leather/Synthetic', '75.00']
# ['Fila', 'Spaghetti', 'Basketball', 'Men', '10.5', 'White', 'Leather', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '11', 'Black', 'Leather', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Women', '7', 'Cream', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'White/Black', 'Synthetic', '75.00']
# ['Fila', 'Spaghetti', 'Fashion', 'Men', '9.5', 'White/Navy', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '8.5', 'Red/White', 'Synthetic/Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'Pink', 'Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'White/Red', 'Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'White/Red', 'Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7', 'Pink', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '8.5', 'White/Navy/Red', 'Synthetic/Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '11', 'White/Navy', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'Blue', 'Synthetic', '75.00']
# ['Fila', 'V94M Low', 'Fashion', 'Women', '7', 'White/Pink', 'Leather', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Men', '10.5', 'Black/Gold', 'Leather/Suede', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '10', 'White/Black', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7', 'White', 'Synthetic', '75.00']
# ['Fila', 'Disruptor III', 'Fashion', 'Women', '8.5', 'White', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '9.5', 'Grey/Pink', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7', 'Pink', 'Leather/Synthetic', '75.00']
# ['Fila', 'Ray Tracer Evo', 'Fashion', 'Men', '11', 'Black/White', 'Synthetic', '75.00']
# ['Fila', 'Venom', 'Fashion', 'Men', '11', 'Grey', 'Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'V94M', 'Fashion', 'Women', '8.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'V94M', 'Fashion', 'Women', '8.5', 'White/Blue', 'Leather/Synthetic', '75.00']
# ['Fila', 'Trailblazer', 'Fashion', 'Women', '8', 'Brown', 'Leather', '75.00']
# ['Fila', 'Mindblower', 'Fashion', 'Women', '7.5', 'White', 'Leather', '75.00']
# ['Fila', 'Ray Tracer', 'Fashion', 'Men', '10', 'Black', 'Synthetic', '70.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '11', 'White/Navy', 'Leather', '70.00']
# ['Fila', 'F-13', 'Fashion', 'Men', '10', 'White', 'Leather', '70.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9', 'White', 'Leather', '70.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '9', 'White', 'Leather', '70.00']
# ['Fila', 'D-Formation', 'Casual', 'Women', '8.5', 'White', 'Leather', '70.00']
# ['Fila', 'Mindblower', 'Fashion', 'Men', '9', 'Grey', 'Synthetic', '70.00']
# ['Fila', 'D-Formation', 'Fashion', 'Women', '6', 'White/Black', 'Leather/Synthetic', '70.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '11', 'White/Navy/Red', 'Leather', '70.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '9.5', 'White/Red', 'Leather/Synthetic', '70.00']
# ['Fila', 'D-Formation', 'Fashion', 'Men', '11', 'White', 'Leather', '70.00']
# ['Fila', 'Trail Blazer', 'Hiking', 'Women', '9.5', 'Green', 'Suede/Leather', '70.00']
# ['Fila', 'Trigate', 'Running', 'Women', '7', 'Black/Pink', 'Synthetic/Mesh', '70.00']
# ['Fila', 'Strada', 'Fashion', 'Men', '11', 'White/Red/Blue', 'Synthetic', '70.00']
# ['Fila', 'Spaghetti', 'Fashion', 'Women', '7', 'White', 'Leather/Synthetic', '70.00']
# ['Fila', 'Original Fitness', 'Casual', 'Women', '9', 'White', 'Leather', '70.00']
# ['Fila', 'Original Fitness', 'Casual', 'Men', '10', 'White', 'Leather', '70.00']
# ...
# ['Reebok', 'Club MEMT', 'Casual', 'Men', '9.5', 'White/Grey', 'Leather', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Women', '7.5', 'Pink', 'Nylon', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Women', '7.5', 'Pink', 'Nylon', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '9.5', 'Black', 'Nylon', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '10', 'Grey', 'Nylon', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '10.5', 'Collegiate Navy', 'Nylon/Suede', '65.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '10.5', 'Black', 'Nylon', '60.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '11.5', 'Blue/White', 'Nylon', '60.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '11', 'Black', 'Nylon/Suede', '60.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Men', '12', 'Navy', 'Nylon', '60.00']
# ['Reebok', 'Classic Nylon', 'Casual', 'Women', '7', 'Pink', 'Nylon', '60.00']
#
# Brand: Skechers
# ['Skechers', 'GOrun Razor Excess', 'Running', 'Men', '9', 'Black/Yellow', 'Mesh', '125.00']
# ['Skechers', 'Go Run Razor 3', 'Running', 'Men', '9', 'Black', 'Mesh', '110.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Navy', 'Mesh/Synthetic', '110.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '7', 'Grey/Pink', 'Mesh', '105.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Black', 'Mesh', '100.00']
# ['Skechers', 'GOrun 7+', 'Running', 'Women', '8', 'Black/Pink', 'Mesh', '95.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '8.5', 'Black', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '7.5', 'Pink', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7.5', 'Black', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Men', '8.5', 'Grey', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Men', '11', 'Grey', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '6.5', 'Grey/Pink', 'Mesh', '90.00']
# ['Skechers', 'Go Run Ride 8', 'Running', 'Women', '7.5', 'Black/Pink', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Elite', 'Running', 'Women', '7', 'Grey/Pink', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '10', 'Blue', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '9.5', 'Blue', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7.5', 'Navy', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning Premier', 'Running', 'Women', '6.5', 'Black/White', 'Mesh', '90.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Men', '11', 'Black', 'Mesh', '85.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '8', 'Navy', 'Mesh', '85.00']
# ['Skechers', 'Max Cushioning Elite', 'Walking', 'Women', '8', 'Navy', 'Mesh', '80.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Men', '9.5', 'Black', 'Mesh', '80.00']
# ['Skechers', 'Max Cushioning Premier', 'Walking', 'Women', '7', 'Grey', 'Mesh', '80.00']
# ['Skechers', 'Max Cushioning', 'Running', 'Women', '7', 'Black', 'Mesh', '75.00']
# ['Skechers', 'Max Cushioning', 'Walking', 'Women', '9', 'Black', 'Mesh', '75.00']
# ['Skechers', 'Arch Fit', 'Walking', 'Women', '7.5', 'Grey', 'Mesh', '70.00']
# ['Skechers', 'Uno Bold Move', 'Casual', 'Women', '8.5', 'Black/White', 'Synthetic', '70.00']
# ['Skechers', 'Energy Burst', 'Running', 'Women', '8', 'Black', 'Mesh', '70.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '9.5', 'White/Black', 'Leather', '70.00']
# ['Skechers', 'Equalizer 4.0', 'Training', 'Women', '8.5', 'Black', 'Knit', '70.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Women', '7.5', 'Black', 'Mesh', '70.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Women', '9', 'Grey/Pink', 'Knit', '70.00']
# ['Skechers', 'Solar Fuse', 'Walking', 'Women', '8', 'Grey', 'Mesh', '70.00']
# ['Skechers', 'Go Run Mojo Pep', 'Running', 'Men', '8.5', 'Black', 'Mesh', '70.00']
# ['Skechers', 'Flex Appeal 4.0', 'Training', 'Men', '8.5', 'Grey/Orange', 'Knit', '70.00']
# ['Skechers', 'Uno Bold', 'Lifestyle', 'Women', '7.5', 'Pink/White', 'Synthetic', '70.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Men', '9.5', 'Grey', 'Knit', '70.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '7', 'Black', 'Synthetic', '65.00']
# ['Skechers', 'Elite Flex', 'Walking', 'Men', '10', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'Equalizer 4.0', 'Training', 'Women', '8.5', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Arch Fit Refine', 'Walking', 'Women', '6.5', 'Navy', 'Mesh', '65.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '8', 'White', 'Leather', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '9', 'Grey', 'Mesh', '65.00']
# ['Skechers', 'Equalizer 4.0', 'Walking', 'Men', '12', 'Navy', 'Mesh', '65.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '6.5', 'Black/White', 'Synthetic', '65.00']
# ['Skechers', "D'Lites", 'Lifestyle', 'Women', '8.5', 'White', 'Leather/Synthetic', '65.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Women', '7.5', 'Grey', 'Knit', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '10', 'Black', 'Mesh', '65.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '12', 'White', 'Synthetic/Leather', '65.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7.5', 'Black/Pink', 'Mesh', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '9', 'Charcoal', 'Mesh', '65.00']
# ['Skechers', 'Stamina', 'Training', 'Men', '9', 'Black', 'Leather', '65.00']
# ['Skechers', 'Summits', 'Walking', 'Men', '12', 'Black', 'Mesh', '65.00']
# ['Skechers', 'GOwalk 5', 'Walking', 'Men', '9', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Men', '8', 'Navy', 'Mesh', '65.00']
# ['Skechers', 'Elite Flex Wasick', 'Training', 'Men', '8', 'Navy', 'Mesh', '65.00']
# ['Skechers', "D'Lites", 'Walking', 'Men', '11', 'White', 'Leather', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Men', '11', 'Black', 'Mesh', '65.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '7.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Summits - Quick Getaway', 'Walking', 'Men', '9', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Equalizer 4.0', 'Walking', 'Women', '7', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'GOrun Mojo 2.0', 'Running', 'Men', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Summits', 'Walking', 'Women', '7.5', 'Black/Pink', 'Mesh', '60.00']
# ['Skechers', 'Ultra Flex 2.0', 'Walking', 'Women', '7.5', 'Navy/White', 'Mesh', '60.00']
# ['Skechers', 'Go Run 600', 'Running', 'Women', '6', 'Pink', 'Mesh', '60.00']
# ['Skechers', 'Summits - Quick Lapse', 'Walking', 'Women', '8', 'Black/Pink', 'Mesh', '60.00']
# ['Skechers', "D'Lites", 'Walking', 'Women', '7.5', 'Black', 'Leather/Synthetic', '60.00']
# ['Skechers', 'Summits', 'Training', 'Men', '11', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Energy Wave Linxe', 'Walking', 'Women', '8', 'Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '7', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '9.5', 'Grey/Pink', 'Mesh', '60.00']
# ['Skechers', 'Summits', 'Walking', 'Women', '9', 'Black/Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '8', 'Grey', 'Mesh', '60.00']
# ['Skechers', "D'Lites Fresh Start", 'Walking', 'Men', '10.5', 'Black', 'Leather', '60.00']
# ['Skechers', 'Go Walk 5', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 6', 'Walking', 'Men', '10.5', 'Black/Grey', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Women', '7.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Run Mojo', 'Running', 'Men', '8', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Go Walk 6', 'Walking', 'Men', '9.5', 'Black', 'Mesh', '60.00']
# ['Skechers', 'Summits - New World', 'Walking', 'Men', '10', 'Black', 'Mesh', '59.00']
# ['Skechers', 'Go Run Mojo Pep', 'Running', 'Women', '8.5', 'Black/White', 'Mesh', '55']
# ['Skechers', 'Go Run Mojo 2.0', 'Running', 'Men', '9', 'Black', 'Mesh', '55.00']
# ['Skechers', 'Summits', 'Training', 'Men', '8', 'Grey', 'Mesh', '55.00']
# ['Skechers', 'Go Walk Joy', 'Walking', 'Women', '6.5', 'Black', 'Mesh', '54.99']
# ['Skechers', 'Dynamight 2.0', 'Training', 'Women', '9', 'Black', 'Mesh', '50.00']
#
# Brand: Vans
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black', 'Suede', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6', 'Black', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '6', 'Red/White', 'Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Checkerboard', 'Canvas', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas/Leather', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '6.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '9.5', 'Purple', 'Canvas/Suede', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Red', 'Canvas/Suede', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9.5', 'Blue/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '6.5', 'Blue/White', 'Suede/Canvas', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9.5', 'Red', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '8', 'Black/White', 'Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10', 'Black/White', 'Suede/Canvas', '70.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '8', 'Red/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Red/White', 'Suede/Canvas', '70.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '10.5', 'Black/White', 'Canvas/Suede', '70.00']
# ['Vans', 'Old Skool', 'Skate', 'Men', '8.5', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Era 95 DX', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7', 'Black/White', 'Canvas/Suede', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Yellow', 'Suede', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Yellow', 'Canvas/Suede', '65.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Women', '7.5', 'Pink', 'Suede/Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Pink/White', 'Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '7.5', 'Red', 'Suede', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '8', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Women', '9', 'Purple', 'Suede/Canvas', '65.00']
# ['Vans', 'SK8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Suede/Canvas', '65.00']
# ['Vans', 'Sk8-Hi', 'Skate', 'Men', '9', 'Black/White', 'Canvas/Suede', '65.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'White', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Green', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Pink', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Black', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '8.5', 'Red', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Red', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '8', 'Multi-color', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Men', '10.5', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black/White', 'Canvas', '55.00']
# ['Vans', 'Authentic', 'Skate', 'Women', '6', 'White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '7', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Green', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '6.5', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '7', 'Pink/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '10.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '8.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '8', 'Black/White Checkerboard', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '8', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '7', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '9.5', 'Checkerboard Black/White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '8.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '7.5', 'Pink', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '8.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '9', 'Checkerboard Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '8', 'True White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Women', '8.5', 'Checkered', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Black', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Women', '6.5', 'Checkerboard', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '8', 'Grey', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '10', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Casual', 'Men', '8.5', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '10', 'Black', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '6.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '8', 'Navy', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Red', 'Canvas', '50.00']
# ['Vans', 'Slip-On', 'Skate', 'Men', '9', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Women', '6', 'Black/White', 'Canvas', '50.00']
# ['Vans', 'Era', 'Skate', 'Men', '9.5', 'Black/White', 'Canvas', '50.00']

# %% [markdown]
# ### **Part 2: Data Manipulation using DataFrame**

# %%
# Load the dataset into dataframe
df = spark.read.csv('shoe-prices.csv', header=True, inferSchema=True)

# Count the number of rows
row_count = df.count()
print(f'The initial number of rows in the DataFrame: {row_count}')

# Show the first few rows of the DataFrame
df.show()
# Out:
# The initial number of rows in the DataFrame: 1006
# +-----------+------------------+----------+------+-------+-----------+-----------------+-----------+
# |      Brand|             Model|      Type|Gender|   Size|      Color|         Material|Price (USD)|
# +-----------+------------------+----------+------+-------+-----------+-----------------+-----------+
# |       Nike|      Air Jordan 1|Basketball|   Men|  US 10|  Red/Black|          Leather|   $170.00 |
# |     Adidas|    Ultra Boost 21|   Running|   Men| US 9.5|      Black|        Primeknit|   $180.00 |
# |     Reebok|   Classic Leather|    Casual|   Men|  US 11|      White|          Leather|    $75.00 |
# |   Converse|      Chuck Taylor|    Casual| Women|   US 8|       Navy|           Canvas|    $55.00 |
# |       Puma|      Future Rider| Lifestyle| Women| US 7.5|       Pink|             Mesh|    $80.00 |
# |       Vans|         Old Skool|     Skate|   Men| US 8.5|Black/White|     Suede/Canvas|    $65.00 |
# |New Balance|             990v5|   Running| Women| US 6.5|       Grey|       Suede/Mesh|   $175.00 |
# |      Asics|     Gel-Kayano 28|   Running|   Men|US 10.5|       Blue|             Mesh|   $160.00 |
# |       Fila|      Disruptor II|   Fashion| Women|   US 9|      White|Leather/Synthetic|    $65.00 |
# |   Skechers|    Go Run Razor 3|   Running|   Men|   US 9|      Black|             Mesh|   $110.00 |
# |       Nike|       Air Max 270|   Running| Women|   US 7|       Pink|             Mesh|   $150.00 |
# |     Adidas|        Stan Smith|    Casual|   Men|   US 9|White/Green|          Leather|    $80.00 |
# |     Reebok|         Club C 85|    Casual| Women| US 8.5|       Pink|          Leather|    $70.00 |
# |   Converse|          One Star|     Skate|   Men|  US 10|      Black|            Suede|    $75.00 |
# |       Puma|           RS-Fast| Lifestyle|   Men| US 9.5|     Yellow|Leather/Synthetic|   $110.00 |
# |       Vans|         Authentic|     Skate| Women|   US 6|      White|           Canvas|    $50.00 |
# |New Balance|Fresh Foam 1080v11|   Running|   Men|US 11.5|       Blue|             Mesh|   $150.00 |
# |      Asics|     Gel-Nimbus 23|   Running| Women|   US 8|     Purple|             Mesh|   $150.00 |
# |       Fila|        Ray Tracer|   Fashion|   Men|  US 10|      Black|        Synthetic|    $70.00 |
# |   Skechers|          Arch Fit|   Walking| Women| US 7.5|       Grey|             Mesh|    $70.00 |
# +-----------+------------------+----------+------+-------+-----------+-----------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import regexp_replace, col

# Remove "US" from the Size column
df_cleaned = df.withColumn('Size', regexp_replace(col('Size'), 'US ', ''))

# Remove the dollar sign and any extra spaces from the Price (USD) column, then convert to float
df_cleaned = df_cleaned.withColumn('Price (USD)', regexp_replace(col('Price (USD)'), '[$,]', '').cast('float'))

# Rename the Size column to Size (US)
df_cleaned = df_cleaned.withColumnRenamed('Size', 'Size (US)')

# Clean the Type column by replacing "CrossFit" with "Crossfit"
df_cleaned = df_cleaned.withColumn('Type', regexp_replace(col('Type'), 'CrossFit', 'Crossfit'))

# Show the cleaned DataFrame
print('This is the cleaned dataframe')
df_cleaned.show()
# Out:
# This is the cleaned dataframe
# +-----------+------------------+----------+------+---------+-----------+-----------------+-----------+
# |      Brand|             Model|      Type|Gender|Size (US)|      Color|         Material|Price (USD)|
# +-----------+------------------+----------+------+---------+-----------+-----------------+-----------+
# |       Nike|      Air Jordan 1|Basketball|   Men|       10|  Red/Black|          Leather|      170.0|
# |     Adidas|    Ultra Boost 21|   Running|   Men|      9.5|      Black|        Primeknit|      180.0|
# |     Reebok|   Classic Leather|    Casual|   Men|       11|      White|          Leather|       75.0|
# |   Converse|      Chuck Taylor|    Casual| Women|        8|       Navy|           Canvas|       55.0|
# |       Puma|      Future Rider| Lifestyle| Women|      7.5|       Pink|             Mesh|       80.0|
# |       Vans|         Old Skool|     Skate|   Men|      8.5|Black/White|     Suede/Canvas|       65.0|
# |New Balance|             990v5|   Running| Women|      6.5|       Grey|       Suede/Mesh|      175.0|
# |      Asics|     Gel-Kayano 28|   Running|   Men|     10.5|       Blue|             Mesh|      160.0|
# |       Fila|      Disruptor II|   Fashion| Women|        9|      White|Leather/Synthetic|       65.0|
# |   Skechers|    Go Run Razor 3|   Running|   Men|        9|      Black|             Mesh|      110.0|
# |       Nike|       Air Max 270|   Running| Women|        7|       Pink|             Mesh|      150.0|
# |     Adidas|        Stan Smith|    Casual|   Men|        9|White/Green|          Leather|       80.0|
# |     Reebok|         Club C 85|    Casual| Women|      8.5|       Pink|          Leather|       70.0|
# |   Converse|          One Star|     Skate|   Men|       10|      Black|            Suede|       75.0|
# |       Puma|           RS-Fast| Lifestyle|   Men|      9.5|     Yellow|Leather/Synthetic|      110.0|
# |       Vans|         Authentic|     Skate| Women|        6|      White|           Canvas|       50.0|
# |New Balance|Fresh Foam 1080v11|   Running|   Men|     11.5|       Blue|             Mesh|      150.0|
# |      Asics|     Gel-Nimbus 23|   Running| Women|        8|     Purple|             Mesh|      150.0|
# |       Fila|        Ray Tracer|   Fashion|   Men|       10|      Black|        Synthetic|       70.0|
# |   Skechers|          Arch Fit|   Walking| Women|      7.5|       Grey|             Mesh|       70.0|
# +-----------+------------------+----------+------+---------+-----------+-----------------+-----------+
# only showing top 20 rows

# %%
# Remove duplicates
df_cleaned = df_cleaned.dropDuplicates()

# Count and show the cleaned DataFrame without duplicates
row_count_cleaned = df_cleaned.count()
print(f'The number of rows in the DataFrame without duplicates: {row_count_cleaned}')
df_cleaned.show()
# Out:
# The number of rows in the DataFrame without duplicates: 925
# +-----------+------------------+--------+------+---------+-----------+--------------+-----------+
# |      Brand|             Model|    Type|Gender|Size (US)|      Color|      Material|Price (USD)|
# +-----------+------------------+--------+------+---------+-----------+--------------+-----------+
# |New Balance|   Fresh Foam More| Running| Women|        9|Grey/Purple|          Mesh|      165.0|
# |      Asics|   Gel-Quantum 180| Running| Women|      7.5|       Grey|          Mesh|      120.0|
# |   Converse|          Chuck 70|  Casual| Women|      7.5|      Egret|        Canvas|       85.0|
# |     Reebok|Floatride Energy 3| Running|   Men|      8.5|White/Black|Knit/Synthetic|      100.0|
# |       Nike|React Infinity Run| Running|   Men|      9.5| Blue/Green|          Mesh|      160.0|
# |       Nike|      Air Max 2090| Running|   Men|     10.5|      Green|          Mesh|      150.0|
# |     Reebok|            Nano 9|Crossfit|   Men|      9.5| Grey/Black|          Mesh|      130.0|
# |       Fila|        Mindblower| Fashion| Women|        7|      White|     Synthetic|       75.0|
# |   Skechers|           Summits|Training|   Men|        8|       Grey|          Mesh|       55.0|
# |       Nike|       Air Max 270| Running| Women|        7|       Pink|          Mesh|      150.0|
# |     Adidas|Adilette Cloudfoam|  Slides| Women|        6|      Black|     Synthetic|       35.0|
# |   Converse|      Jack Purcell|  Casual|   Men|        9|      White|        Canvas|       65.0|
# |     Reebok|Floatride Energy 3| Running|   Men|        9|      Black|          Mesh|      100.0|
# |       Vans|               Era|   Skate|   Men|      8.5|      Black|        Canvas|       50.0|
# |      Asics|        GT-2000 10| Running|   Men|      9.5|       Grey|          Mesh|      120.0|
# |       Vans|               Era|   Skate| Women|      6.5|      White|        Canvas|       55.0|
# |New Balance| FuelCell Rebel v2| Running|   Men|       10|      Black|          Mesh|      130.0|
# |       Puma|  Calibrate Runner| Running|   Men|      9.5|      Black|          Mesh|       80.0|
# |     Reebok|           Nano X1|Training|   Men|        9|      Black|          Knit|      130.0|
# |     Adidas|Ultraboost 5.0 DNA| Running| Women|      8.5|       Grey|     Primeknit|      180.0|
# +-----------+------------------+--------+------+---------+-----------+--------------+-----------+
# only showing top 20 rows

# %%
# Group by 'Brand' and count the number of shoe models for each brand
brand_model_count = df_cleaned.groupBy("Brand").count()

# Sort the result by count in descending order
brand_model_count_sorted = brand_model_count.orderBy("Count", ascending=False)

# Show the result
brand_model_count_sorted.show()
# Out:
# +-----------+-----+
# |      Brand|count|
# +-----------+-----+
# |New Balance|   98|
# |       Fila|   97|
# |       Nike|   95|
# |      Asics|   95|
# |       Puma|   94|
# |     Reebok|   94|
# |     Adidas|   94|
# |   Skechers|   87|
# |       Vans|   87|
# |   Converse|   84|
# +-----------+-----+

# %% [markdown]
# ### **Running SQL query to answer questions**

# %%
# Register the DataFrame as a temporary SQL table
df_cleaned.createOrReplaceTempView("shoes")

# Run an SQL query to find the average price of different types of shoes
average_price_by_type = spark.sql("""
    SELECT Type, ROUND(AVG(`Price (USD)`), 2) as Average_Price_USD
    FROM shoes
    GROUP BY Type
    ORDER BY Average_Price_USD DESC""")

# Show the results
average_price_by_type.show()
# Out:
# +--------------+-----------------+
# |          Type|Average_Price_USD|
# +--------------+-----------------+
# | Weightlifting|            187.5|
# |      Crossfit|            130.0|
# |Cross-training|            130.0|
# |       Running|           129.11|
# |     Lifestyle|           122.71|
# |    Basketball|           114.88|
# | Trail Running|           113.33|
# |      Training|           111.67|
# |        Racing|            110.0|
# |         Trail|            99.17|
# |         Retro|             90.0|
# |       Fashion|            84.11|
# |        Casual|            80.07|
# |        Hiking|             77.5|
# |       Walking|            65.09|
# |         Skate|            62.36|
# |        Slides|            31.67|
# +--------------+-----------------+

# %%
# Run an SQL query to find the top 1 most expensive model per type of shoe
top_1_model_per_type = spark.sql("""
  SELECT Type, Brand, Model, `Price (USD)`
  FROM (
    SELECT Type, Brand, Model, `Price (USD)`, ROW_NUMBER() OVER(PARTITION BY Type ORDER BY `Price (USD)` DESC) as Rank
    FROM shoes
  ) tmp
  WHERE Rank = 1
  ORDER BY Type """)

# Show the result
top_1_model_per_type.show(top_1_model_per_type.count(), truncate=False)
# Out:
# +--------------+-----------+--------------------+-----------+
# |Type          |Brand      |Model               |Price (USD)|
# +--------------+-----------+--------------------+-----------+
# |Basketball    |Nike       |Air Jordan 1        |170.0      |
# |Casual        |Adidas     |Yeezy Boost 350 V2  |220.0      |
# |Cross-training|Reebok     |Nano 9              |130.0      |
# |Crossfit      |Reebok     |Nano 9              |130.0      |
# |Fashion       |Adidas     |Yeezy Boost 350 V2  |220.0      |
# |Hiking        |Fila       |Trailblazer         |85.0       |
# |Lifestyle     |Adidas     |Yeezy Boost 350 V2  |220.0      |
# |Racing        |New Balance|1500v6              |110.0      |
# |Retro         |New Balance|327                 |100.0      |
# |Running       |Nike       |ZoomX Vaporfly Next%|250.0      |
# |Skate         |Nike       |SB Dunk Low         |100.0      |
# |Slides        |Adidas     |Adilette Cloudfoam  |35.0       |
# |Trail         |New Balance|Fresh Foam Hierro v6|135.0      |
# |Trail Running |New Balance|Fresh Foam Hierro v6|135.0      |
# |Training      |Reebok     |Nano X1             |130.0      |
# |Walking       |Skechers   |Max Cushioning      |90.0       |
# |Weightlifting |Reebok     |Legacy Lifter       |200.0      |
# +--------------+-----------+--------------------+-----------+

# %%
# Run an SQL query to analyze the relationship between shoe material and price
material_price_analysis = spark.sql("""
    SELECT Material, ROUND(AVG(`Price (USD)`), 2) AS Average_Price_USD
    FROM shoes
    GROUP BY Material
    ORDER BY Average_Price_USD DESC
""")

# Show the results
material_price_analysis.show(material_price_analysis.count())
# Out:
# +--------------------+-----------------+
# |            Material|Average_Price_USD|
# +--------------------+-----------------+
# | Primeknit/Synthetic|            220.0|
# |        Mesh/Leather|            180.0|
# |           Primeknit|           168.73|
# |             Flyknit|           158.82|
# |      Mesh/Synthetic|           133.33|
# |     Textile/Leather|            130.0|
# |           Flexweave|            130.0|
# |Flexweave/Cushioning|            130.0|
# |             Textile|            130.0|
# |      Flexweave/Knit|            130.0|
# | Flexweave/Synthetic|            130.0|
# |      Knit/Synthetic|           123.33|
# |        Leather/Mesh|            120.0|
# |      Synthetic/Mesh|            115.0|
# |                Mesh|           112.67|
# |                Knit|           112.33|
# |          Mesh/Suede|            110.0|
# |   Synthetic/Textile|            105.0|
# |       Leather/Suede|            105.0|
# |          Suede/Mesh|           103.75|
# |         Suede/Nylon|             92.5|
# |             Leather|            88.68|
# |   Leather/Synthetic|             87.0|
# |           Synthetic|            86.44|
# |   Synthetic/Leather|            85.83|
# |       Suede/Leather|             85.0|
# |       Suede/Textile|            83.33|
# |      Canvas/Leather|             70.0|
# |        Suede/Canvas|            68.41|
# |        Canvas/Suede|            68.33|
# |              Canvas|            68.16|
# |               Suede|            68.16|
# |         Nylon/Suede|            63.33|
# |               Nylon|             63.0|
# +--------------------+-----------------+
